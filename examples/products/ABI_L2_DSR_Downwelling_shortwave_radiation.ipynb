# %%
asdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3723/2827374946.py in <cell line: 1>()
# ----> 1 asdf
#
# NameError: name 'asdf' is not defined

# %% [markdown]
# # Imports

# %%
import pathlib as pl
import nesdis_aws
import nesdis_gml_synergy.satlab as ngs
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad
import os
os.getpid()
# Out:
# 3688481

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# warnings.filterwarnings("default")

# %%
plt.rcParams['figure.dpi'] = 200

# %% [markdown]
# # download some data

# %%
reload(nesdis_aws.nesdis_aws)
reload(nesdis_aws)
# Out:
# <module 'nesdis_aws' from '/mnt/telg/prog/nesdis_aws/nesdis_aws/__init__.py'>

# %%
product = 'DSR' #FDC
# path2folder_local=f'/mnt/telg/data/nesdis/goes/ABI_L2_{product}/'
path2folder_local=f'/export/htelg/tmp/'
# pl.Path(path2folder_local).mkdir()
query = nesdis_aws.AwsQuery(path2folder_local=path2folder_local,
                            satellite='16',
                            product=f'ABI-L2-{product}',
                            scan_sector='C',
                            # start='2020-09-30 18:00:00',
                            # end='2020-09-30 19:35:00',
                            start='2020-08-01 18:00:00',
                            # end='2018-11-01 00:00:00',
                            end='2020-08-01 18:05:00',
                            verbose = True
                           )

# %%
query.workplan
# Out:
# Get workplan:
# workplan done
#                                                          path2file_aws  \
# 2020-08-01 18:01:15  noaa-goes16/ABI-L2-DSRC/2020/214/18/OR_ABI-L2-...
#
#                                                        path2file_local
# 2020-08-01 18:01:15  /export/htelg/tmp/OR_ABI-L2-DSRC-M6_G16_s20202...

# %%
print(query.info_on_current_query())
# Out:
# no of files: 1
# estimated disk usage: 0 mb
# remaining disk space after download: 52 %

# %%
query.product_available_since
# Out:
# Timestamp('2019-12-06 00:00:00')

# %%
query.download()
# Out:
# [None]

# %%
query.workplan.path2file_local[0]
# Out:
# PosixPath('/export/htelg/tmp/OR_ABI-L2-DSRC-M6_G16_s20202141801156_e20202141803528_c20202141811072.nc')

# %% [markdown]
# # open

# %%
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad
stations = surfrad.network.stations

# %%
reload(ngs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17686/1869351279.py in <cell line: 1>()
# ----> 1 reload(ngs)
#
# NameError: name 'ngs' is not defined

# %%
fn = '/export/htelg/tmp/OR_ABI-L2-DSRC-M6_G16_s20202141801156_e20202141803528_c20202141811072.nc'

# %%
ds = xr.open_dataset(fn)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                 (lat: 166, lon: 394,
#                                              number_of_time_bounds: 2,
#                                              number_of_image_bounds: 2,
#                                              number_of_LZA_bounds: 2,
#                                              number_of_SZA_bounds: 2,
#                                              number_of_wavelength_bounds: 2)
# Coordinates:
#     t                                       datetime64[ns] ...
#   * lat                                     (lat) float64 55.62 55.38 ... 14.38
#   * lon                                     (lon) float64 -151.6 ... -53.38
#     lat_image                               float32 ...
#     lon_image                               float32 ...
#     retrieval_local_zenith_angle            float32 ...
#     quantitative_local_zenith_angle         float32 ...
#     retrieval_solar_zenith_angle            float32 ...
#     quantitative_solar_zenith_angle         float32 ...
#     dsr_product_wavelength                  float32 ...
# Dimensions without coordinates: number_of_time_bounds, number_of_image_bounds,
#                                 number_of_LZA_bounds, number_of_SZA_bounds,
#                                 number_of_wavelength_bounds
# Data variables: (12/32)
#     DSR                                     (lat, lon) float32 ...
#     DQF                                     (lat, lon) float32 ...
#     time_bounds                             (number_of_time_bounds) datetime64[ns] ...
#     goes_lat_lon_projection                 int32 ...
#     lat_image_bounds                        (number_of_image_bounds) float32 ...
#     lon_image_bounds                        (number_of_image_bounds) float32 ...
#     ...                                      ...
#     std_dev_dsr                             float32 ...
#     percent_uncorrectable_GRB_errors        float32 ...
#     percent_uncorrectable_L0_errors         float32 ...
#     algorithm_dynamic_input_data_container  int32 ...
#     processing_parm_version_container       int32 ...
#     algorithm_product_version_container     int32 ...
# Attributes: (12/29)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     cdm_data_type:             Image
#     time_coverage_start:       2020-08-01T18:01:15.6Z
#     time_coverage_end:         2020-08-01T18:03:52.8Z
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
#     id:                        b691e1e4-93b3-4afa-a72d-23adef4cc140

# %%
len(ds.lon.shape)
# Out:
# 1

# %%
sat_ds = ngs.open_file(fn, verbose=True)
# Out:
# product name: ABI-L2-DSRC-M6
# ---------------------------------------------------------------------------
# GoesExceptionVerionNotRecognized          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sat_ds = ngs.open_file(fn, verbose=True)
#
# File /export/htelg/prog/nesdis_gml_synergy/nesdis_gml_synergy/satlab.py:107, in open_file(p2f, auto_assign_product, bypass_time_unit_error, extent, verbose)
#     105         print('identified as: ABI_L2_CTP.')
#     106 elif product_name[:-4] == 'ABI-L2-DSR':
# --> 107     classinst = ABI_L2_DSR(ds)
#     108     if verbose:
#     109         print('identified as: ABI_L2_DSR.')
#
# File /export/htelg/prog/nesdis_gml_synergy/nesdis_gml_synergy/satlab.py:2060, in ABI_L2_DSR.__init__(self, *args)
#    2051     self.qf_managment = QfManagment(self,
#    2052                                     qf_representation='as_is',
#    2053                                     # qf_representation='binary',
#    (...)
#    2056                                     # number_of_bits=8
#    2057                                    )
#    2059 else:
# -> 2060     raise GoesExceptionVerionNotRecognized(self)
#
# GoesExceptionVerionNotRecognized: The version of this product (M6) has not been tested and might return false results.

# %%
sat_ds.ds
# Out:
# <xarray.Dataset>
# Dimensions:                                 (lat: 166, lon: 394,
#                                              number_of_time_bounds: 2,
#                                              number_of_image_bounds: 2,
#                                              number_of_LZA_bounds: 2,
#                                              number_of_SZA_bounds: 2,
#                                              number_of_wavelength_bounds: 2)
# Coordinates:
#     t                                       datetime64[ns] ...
#   * lat                                     (lat) float32 55.62 55.38 ... 14.38
#   * lon                                     (lon) float32 -151.6 ... -53.38
#     lat_image                               float32 ...
#     lon_image                               float32 ...
#     retrieval_local_zenith_angle            float32 ...
#     quantitative_local_zenith_angle         float32 ...
#     retrieval_solar_zenith_angle            float32 ...
#     quantitative_solar_zenith_angle         float32 ...
#     dsr_product_wavelength                  float32 ...
# Dimensions without coordinates: number_of_time_bounds, number_of_image_bounds,
#                                 number_of_LZA_bounds, number_of_SZA_bounds,
#                                 number_of_wavelength_bounds
# Data variables: (12/32)
#     DSR                                     (lat, lon) float32 ...
#     DQF                                     (lat, lon) float32 ...
#     time_bounds                             (number_of_time_bounds) datetime64[ns] ...
#     goes_lat_lon_projection                 int32 ...
#     lat_image_bounds                        (number_of_image_bounds) float32 ...
#     lon_image_bounds                        (number_of_image_bounds) float32 ...
#     ...                                      ...
#     std_dev_dsr                             float32 ...
#     percent_uncorrectable_GRB_errors        float32 ...
#     percent_uncorrectable_L0_errors         float32 ...
#     algorithm_dynamic_input_data_container  int32 ...
#     processing_parm_version_container       int32 ...
#     algorithm_product_version_container     int32 ...
# Attributes: (12/29)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     cdm_data_type:             Image
#     time_coverage_start:       2021-05-23T18:01:16.9Z
#     time_coverage_end:         2021-05-23T18:03:54.2Z
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
#     id:                        3386a01d-60c2-4fee-b8e8-9465d58f8837

# %%
sat_ds.valid_2D_variables

# %%
list(sat_ds.ds.variables)

# %%
proj = sat_ds.project_on_sites(stations)

# %%
proj.projection2area.sel(site = 'BND', stats = 'mean', radius = 50, 
                         # data_quality = 'good'
                        )

# %%
proj.projection2point

# %% [markdown]
# # Plot on map

# %%
scale = 0.5
width=2800000 *scale
height=1700000 * scale
a, bmap = surfrad.network.stations.Table_Mountain.plot(width=width, height=height)
bmap, pc, cb = sat_ds.plot('Temp', bmap = bmap)
bmap.drawcounties()
# f = plt.gcf()
# pc.set_clim(vmax= 10)

# %% [markdown]
# # Download and project

# %%
import pathlib as pl
import nesdis_aws
import nesdis_gml_synergy.satlab as ngs
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad
import os
os.getpid()
# Out:
# 12304

# %%
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad

stations = surfrad.network.stations

# %%
# def function(row, stations):#, alt_var = None):
#     # if isinstance(alt_var, type(None)):
#     #     alt_var = variable
#     # read the file
#     ngsinst = ngs.open_file(row.path2file_local)
    
#     # project to stations
#     projection = ngsinst.project_on_sites(stations)

#     # merge closest gridpoint and area
#     point = projection.projection2point.copy()#.sel(site = 'TBL')
#     point['DQF'] = point.DQF.astype(int) # for some reason this was float64... because there are some nans in there
    
#     # change var names to distinguish from area
#     for var in ngsinst.valid_2D_variables:
#         point = point.rename({var: f'{var}_on_pixel',})
#     point = point.rename({'DQF': 'DQF_on_pixel'})
    
#     # merge aerea and point
#     ds = projection.projection2area.merge(point)#.rename({alt_var: f'{alt_var}_on_pixel', 'DQF': 'DQF_on_pixel'}))
    
#     # add a time stamp
#     dt = pd.Series([pd.to_datetime(ngsinst.ds.attrs['time_coverage_start']), pd.to_datetime(ngsinst.ds.attrs['time_coverage_end'])]).mean().to_datetime64()
#     ds = ds.expand_dims({'datetime': [dt]}, )
    
#     # there was another time coordinate without dimention though ... dropit
#     ds = ds.drop_vars('t')

#     # global attribute
#     ds.attrs['info'] = ('This file contains a projection of satellite data onto SURFRAD sites.\n'
#                          'It includes the closest pixel data as well as the average over circular\n'
#                          'areas with various radii. Note, for the averaged data only data is\n'
#                          'considered with a qulity flag given by the prooduct class in the\n'
#                          'nesdis_gml_synergy package.')
    

#     # save2file
#     ds.to_netcdf(row.path2file_local_processed)
#     return

# %%
# product = 'DSR'
# # alt_var = 'BCM'# None, if the varialbe name is not equal to product name
# query = nesdis_aws.nesdis_aws.AwsQuery(
#                                         path2folder_local=f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}/',
#                                         satellite='16',
#                                         product=f'ABI-L2-{product}',
#                                         scan_sector='C',
#                                         # start='2020-03-01 18:00:00',
#                                         # end='2020-03-01 18:05:00',
#                                         start='2020-03-01 00:00:00',
#                                         end='2020-06-01 00:00:00',
#                                         # start='2018-08-01 00:00:00',
#                                         # end='2018-11-01 00:00:00',
#                                         process = dict(#concatenate = 'daily',
#                                                        function = lambda row: function(row, stations), #,, alt_var),
#                                                        prefix = f'ABI_L2_{product}_projected2surfrad',
#                                                        path2processed = f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}_projected2surfrad/'),
#                                         # keep_files=True
#                                       )

# # pl.Path(f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}').mkdir()
# # pl.Path(f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}_projected2surfrad/').mkdir()

# %%
reload(ngs)
# Out:
# <module 'nesdis_gml_synergy.satlab' from '/mnt/telg/prog/nesdis_gml_synergy/nesdis_gml_synergy/satlab.py'>

# %%
product = 'DSR'
# alt_var = 'BCM'# None, if the varialbe name is not equal to product name
path2processed = f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}_projected2surfrad.1/'
query = nesdis_aws.nesdis_aws.AwsQuery(
                                        path2folder_local=f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}/',
                                        satellite='16',
                                        product=f'ABI-L2-{product}',
                                        scan_sector='C',
                                        #
                                        # for testing
                                        # start='2020-06-01 18:00:00',
                                        # end='2020-06-01 18:05:00',
                                        #
                                        # all times
                                        # start = '2019-12-06 00:00:00',
                                        # end =   '2022-06-01 00:00:00',
                                        # CPEX spring 2020
                                        start='2020-03-01 00:00:00',
                                        end='2020-06-01 00:00:00',
                                        #
                                        # CPEX original
                                        # start='2018-08-01 00:00:00',
                                        # end='2018-11-01 00:00:00',
                                        process = dict(#concatenate = 'daily',
                                                       function = lambda row: ngs.projection_function(row, stations), #,, alt_var),
                                                       prefix = f'ABI_L2_{product}_projected2surfrad',
                                                       path2processed = path2processed),
                                        # keep_files=True
                                      )

# pl.Path(f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}').mkdir()
# pl.Path(path2processed).mkdir()

# %%
query.workplan
# Out:
# Empty DataFrame
# Columns: [path2file_aws, path2file_local, path2file_local_processed]
# Index: []

# %%
query.process(raise_exception=True)

# %%
ds = xr.open_dataset(query.workplan.path2file_local_processed.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_12304/934861090.py in <cell line: 1>()
# ----> 1 ds = xr.open_dataset(query.workplan.path2file_local_processed.iloc[0])
#
# /mnt/telg/programs/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# /mnt/telg/programs/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1518
#    1519             # validate the location
# -> 1520             self._validate_integer(key, axis)
#    1521
#    1522             return self.obj._ixs(key, axis=axis)
#
# /mnt/telg/programs/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1450         len_axis = len(self.obj._get_axis(axis))
#    1451         if key >= len_axis or key < -len_axis:
# -> 1452             raise IndexError("single positional indexer is out-of-bounds")
#    1453
#    1454     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
ds = xr.open_dataset('/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_DSR_projected2surfrad.1/ABI_L2_DSR_projected2surfrad_20220406_150117.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                     (datetime: 1, radius: 5, stats: 3,
#                                  data_quality: 1, site: 7)
# Coordinates:
#   * datetime                    (datetime) datetime64[ns] 2022-04-06T15:02:35...
#   * radius                      (radius) int64 5 10 25 50 100
#   * stats                       (stats) object 'median' 'mean' 'std'
#   * site                        (site) object 'BND' 'SXF' 'TBL' ... 'GWN' 'PSU'
#   * data_quality                (data_quality) object 'high'
# Data variables:
#     DSR                         (datetime, data_quality, radius, stats, site) float32 ...
#     num_of_valid_points         (datetime, data_quality, radius, site) int64 ...
#     DSR_on_pixel                (datetime, site) float32 ...
#     DSR_on_pixel_DQF_assessed   (datetime, site) int8 ...
#     DQF_on_pixel                (datetime, site) int64 ...
#     argmin_x                    (datetime, site) float32 ...
#     argmin_y                    (datetime, site) float32 ...
#     lon_gritpoint               (datetime, site) float32 ...
#     lat_gridpoint               (datetime, site) float32 ...
#     lon_station                 (datetime, site) float32 ...
#     lat_station                 (datetime, site) float32 ...
#     distance_station_gridpoint  (datetime, site) float32 ...
# Attributes:
#     info:     This file contains a projection of satellite data onto SURFRAD ...

# %%
ds.DSR.sel(site = 'TBL', stats = 'mean', radius = 10)
# Out:
# <xarray.DataArray 'DSR' (datetime: 1, data_quality: 1)>
# array([[411.52142]], dtype=float32)
# Coordinates:
#   * datetime      (datetime) datetime64[ns] 2020-03-01T18:02:32.849999872
#     radius        int64 10
#     stats         <U4 'mean'
#     site          <U3 'TBL'
#   * data_quality  (data_quality) object 'high'
# Attributes:
#     long_name:            ABI L2+ Downward Shortwave Radiation: Surface
#     standard_name:        surface_downwelling_shortwave_flux_in_air
#     valid_range:          [ 0 -6]
#     units:                W m-2
#     resolution:           lon: 0.25 degree lat: 0.25 degree
#     grid_mapping:         goes_lat_lon_projection
#     cell_methods:         retrieval_local_zenith_angle: point (good or degrad...
#     ancillary_variables:  DQF

# %%
ds.DSR_on_pixel.sel(site = 'TBL')
# Out:
# <xarray.DataArray 'DSR_on_pixel' (datetime: 1)>
# array([411.52142], dtype=float32)
# Coordinates:
#   * datetime  (datetime) datetime64[ns] 2020-03-01T18:02:32.849999872
#     site      <U3 'TBL'
# Attributes:
#     long_name:            ABI L2+ Downward Shortwave Radiation: Surface
#     standard_name:        surface_downwelling_shortwave_flux_in_air
#     valid_range:          [ 0 -6]
#     units:                W m-2
#     resolution:           lon: 0.25 degree lat: 0.25 degree
#     grid_mapping:         goes_lat_lon_projection
#     cell_methods:         retrieval_local_zenith_angle: point (good or degrad...
#     ancillary_variables:  DQF
#     coordinates:          retrieval_local_zenith_angle quantitative_local_zen...

# %% [markdown]
# # Concatenate

# %%
reload(ngs)
# Out:
# <module 'nesdis_gml_synergy.satlab' from '/mnt/telg/prog/nesdis_gml_synergy/nesdis_gml_synergy/satlab.py'>

# %%
cc = ngs.Concatonator(path2scraped_files='/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_DSR_projected2surfrad/',
                 path2concat_files ='/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_DSR_projected2surfrad_concat/',
                 datetime_format='ABI_L2_DSR_projected2surfrad_%Y%m%d_%H%M%S.nc',
                 test = False,)

# %%
cc.workplan
# Out:
# Empty DataFrame
# Columns: [path2scraped_files, datetime, date, product_name, path2concat_files, p2rf_exists]
# Index: []

# %%
ds=cc.concat_and_save(save=True, test=False, verbose=False)
