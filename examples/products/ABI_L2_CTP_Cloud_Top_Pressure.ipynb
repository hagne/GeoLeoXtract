# %%
asdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20251/2827374946.py in <cell line: 1>()
# ----> 1 asdf
#
# NameError: name 'asdf' is not defined

# %% [markdown]
# # Imports

# %%
import pathlib as pl
import nesdis_gml_synergy.cloud_interface as ngsci
import nesdis_gml_synergy.satlab as ngs
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad
import os
os.getpid()
# Out:
# 2640325

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# warnings.filterwarnings("default")

# %% [markdown]
# # download some data

# %%
reload(nesdis_aws.nesdis_aws)
reload(nesdis_aws)

# %%
product = 'CTP' #FDC
path2folder_local=f'/export/htelg/tmp/ABI_L2_{product}/'
# pl.Path(path2folder_local).mkdir()
query = ngsci.AwsQuery(path2folder_local=path2folder_local,
                            satellite='16',
                            product=f'ABI-L2-{product}',
                            scan_sector='C',
                            # start='2020-09-30 18:00:00',
                            # end='2020-09-30 19:35:00',
                            start='2023-08-01 13:00:00',
                            # end='2018-11-01 00:00:00',
                            end='2023-08-01 13:05:00',
                            verbose = True,
                            overwrite=True,
                           )

# %%
query.workplan
# Out:
# Get workplan:
# workplan done
#                                                          path2file_aws  \
# 2023-08-01 13:01:17  noaa-goes16/ABI-L2-CTPC/2023/213/13/OR_ABI-L2-...
#
#                                                        path2file_local
# 2023-08-01 13:01:17  /export/htelg/tmp/ABI_L2_CTP/OR_ABI-L2-CTPC-M6...

# %%
query.workplan.iloc[0].path2file_aws.name
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 query.workplan.iloc[0].path2file_aws.name
#
# File /export/htelg/programs/anaconda3/envs/py310telg/lib/python3.10/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /export/htelg/programs/anaconda3/envs/py310telg/lib/python3.10/site-packages/pandas/core/indexing.py:1656, in _iLocIndexer._getitem_axis(self, key, axis)
#    1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
# -> 1656 self._validate_integer(key, axis)
#    1658 return self.obj._ixs(key, axis=axis)
#
# File /export/htelg/programs/anaconda3/envs/py310telg/lib/python3.10/site-packages/pandas/core/indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
query.workplan.iloc[0].path2file_aws.name
# Out:
# 'OR_ABI-L2-CTPC-M6_G16_s20200011301183_e20200011303556_c20200011305529.nc'

# %%
print(query.info_on_current_query())

# %%
query.product_available_since

# %%
query.download()
# Out:
# [None]

# %% [markdown]
# # versions

# %%
dsn = xr.open_dataset(query.workplan.iloc[0].path2file_local.as_posix())
query.workplan.iloc[0].path2file_local.as_posix()
# Out:
# '/export/htelg/tmp/ABI_L2_CTP/OR_ABI-L2-CTPC-M6_G16_s20232131301174_e20232131303547_c20232131306219.nc'

# %%
dso = xr.open_dataset(query.workplan.iloc[0].path2file_local.as_posix())
query.workplan.iloc[0].path2file_local.as_posix()
# Out:
# '/export/htelg/tmp/ABI_L2_CTP/OR_ABI-L2-CTPC-M6_G16_s20200011301183_e20200011303556_c20200011305529.nc'

# %%
# dsn = xr.open_dataset('/export/htelg/tmp/ABI_L2_ADP/OR_ABI-L2-ADPC-M6_G16_s20232131801174_e20232131803547_c20232131805133.nc'
# )
# dso = xr.open_dataset('/export/htelg/tmp/ABI_L2_ADP/OR_ABI-L2-ADPC-M6_G16_s20200011801183_e20200011803556_c20200011805092.nc'
# )

# %%
dsn.t.values, dso.t.values
# Out:
# (numpy.datetime64('2023-08-01T13:02:36.128288000'),
#  numpy.datetime64('2020-01-01T13:02:36.982722944'))

# %%
dsn.DQF
# Out:
# <xarray.DataArray 'DQF' (y: 300, x: 500)>
# [150000 values with dtype=float32]
# Coordinates:
#   * y                   (y) float64 0.1281 0.1278 0.1275 ... 0.04466 0.04438
#   * x                   (x) float64 -0.1012 -0.1009 -0.1007 ... 0.03822 0.0385
#     t                   datetime64[ns] 2023-08-01T13:02:36.128288
#     y_image             float32 ...
#     x_image             float32 ...
#     local_zenith_angle  float32 ...
#     solar_zenith_angle  float32 ...
# Attributes: (12/14)
#     long_name:                       ABI L2+ Cloud Top Pressure data quality ...
#     standard_name:                   status_flag
#     valid_range:                     [0 3]
#     units:                           1
#     flag_values:                     [0 1 2 3 4]
#     flag_meanings:                   good_quality_qf marginal_quality_qf retr...
#     ...                              ...
#     cell_methods:                    local_zenith_angle: point solar_zenith_a...
#     percent_good_quality_qf:         0.61608917
#     percent_marginal_quality_qf:     0.004758305
#     percent_retrieval_attempted_qf:  0.00072218245
#     percent_bad_quality_qf:          0.37843037
#     percent_opaque_retrieval_qf:     0.0

# %%
dsn.DQF.attrs['flag_meanings']  == 'good_quality_qf marginal_quality_qf retrieval_attempted_qf bad_quality_qf opaque_retrieval_qf'
# Out:
# True

# %%
dso.DQF.attrs['flag_meanings']# == 'good_quality_qf invalid_due_to_not_geolocated_qf invalid_due_to_LZA_threshold_exceeded_qf invalid_due_to_bad_or_missing_brightness_temp_data_qf invalid_due_to_clear_or_probably_clear_sky_qf invalid_due_to_unknown_cloud_type_qf invalid_due_to_nonconvergent_retrieval_qf'
# Out:
# 'good_quality_qf invalid_due_to_not_geolocated_qf invalid_due_to_LZA_threshold_exceeded_qf invalid_due_to_bad_or_missing_brightness_temp_data_qf invalid_due_to_clear_or_probably_clear_sky_qf invalid_due_to_unknown_cloud_type_qf invalid_due_to_nonconvergent_retrieval_qf'

# %%
dsn.DQF.attrs['flag_meanings'] == dso.DQF.attrs['flag_meanings']
# Out:
# False

# %%
dsn
# Out:
# <xarray.Dataset>
# Dimensions:                                 (y: 300, x: 500,
#                                              number_of_time_bounds: 2,
#                                              number_of_image_bounds: 2,
#                                              number_of_LZA_bounds: 2,
#                                              number_of_SZA_bounds: 2)
# Coordinates:
#   * y                                       (y) float64 0.1281 ... 0.04438
#   * x                                       (x) float64 -0.1012 ... 0.0385
#     t                                       datetime64[ns] 2023-08-01T13:02:3...
#     y_image                                 float32 ...
#     x_image                                 float32 ...
#     local_zenith_angle                      float32 ...
#     solar_zenith_angle                      float32 ...
# Dimensions without coordinates: number_of_time_bounds, number_of_image_bounds,
#                                 number_of_LZA_bounds, number_of_SZA_bounds
# Data variables: (12/24)
#     PRES                                    (y, x) float32 ...
#     DQF                                     (y, x) float32 ...
#     time_bounds                             (number_of_time_bounds) datetime64[ns] ...
#     goes_imager_projection                  int32 ...
#     y_image_bounds                          (number_of_image_bounds) float32 ...
#     x_image_bounds                          (number_of_image_bounds) float32 ...
#     ...                                      ...
#     solar_zenith_angle_bounds               (number_of_SZA_bounds) float32 ...
#     algorithm_dynamic_input_data_container  int32 ...
#     processing_parm_version_container       int32 ...
#     algorithm_product_version_container     int32 ...
#     percent_uncorrectable_GRB_errors        float32 ...
#     percent_uncorrectable_L0_errors         float32 ...
# Attributes: (12/29)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     date_created:              2023-08-01T13:06:21.9Z
#     time_coverage_start:       2023-08-01T13:01:17.4Z
#     time_coverage_end:         2023-08-01T13:03:54.7Z
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
#     id:                        01a4dd8e-e954-49e7-8306-35e21d3e5672

# %%
dso
# Out:
# <xarray.Dataset>
# Dimensions:                                 (y: 300, x: 500,
#                                              number_of_time_bounds: 2,
#                                              number_of_image_bounds: 2,
#                                              number_of_LZA_bounds: 2,
#                                              number_of_SZA_bounds: 2)
# Coordinates:
#     t                                       datetime64[ns] 2020-01-01T13:02:3...
#   * y                                       (y) float64 0.1281 ... 0.04438
#   * x                                       (x) float64 -0.1012 ... 0.0385
#     y_image                                 float32 ...
#     x_image                                 float32 ...
#     local_zenith_angle                      float32 ...
#     solar_zenith_angle                      float32 ...
# Dimensions without coordinates: number_of_time_bounds, number_of_image_bounds,
#                                 number_of_LZA_bounds, number_of_SZA_bounds
# Data variables: (12/23)
#     PRES                                    (y, x) float32 ...
#     DQF                                     (y, x) float32 ...
#     time_bounds                             (number_of_time_bounds) datetime64[ns] ...
#     goes_imager_projection                  int32 ...
#     y_image_bounds                          (number_of_image_bounds) float32 ...
#     x_image_bounds                          (number_of_image_bounds) float32 ...
#     ...                                      ...
#     algorithm_product_version_container     int32 ...
#     local_zenith_angle_bounds               (number_of_LZA_bounds) float32 ...
#     solar_zenith_angle_bounds               (number_of_SZA_bounds) float32 ...
#     percent_uncorrectable_GRB_errors        float32 ...
#     percent_uncorrectable_L0_errors         float32 ...
#     cloud_pixels                            float64 ...
# Attributes: (12/29)
#     naming_authority:          gov.nesdis.noaa
#     Conventions:               CF-1.7
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     standard_name_vocabulary:  CF Standard Name Table (v35, 20 July 2016)
#     institution:               DOC/NOAA/NESDIS > U.S. Department of Commerce,...
#     project:                   GOES
#     ...                        ...
#     cdm_data_type:             Image
#     time_coverage_start:       2020-01-01T13:01:18.3Z
#     time_coverage_end:         2020-01-01T13:03:55.6Z
#     timeline_id:               ABI Mode 6
#     production_data_source:    Realtime
#     id:                        9d944277-d8e0-4248-8f35-6d8dd0166d29

# %%
dsn.DQF.attrs['flag_meanings'] == dso.DQF.attrs['flag_meanings']
# Out:
# False

# %% [markdown]
# # open

# %%
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad
stations = surfrad.network.stations

# %%
reload(ngs)
reload(ngsci)
# Out:
# <module 'nesdis_gml_synergy.cloud_interface' from '/export/htelg/prog/nesdis_gml_synergy/nesdis_gml_synergy/cloud_interface.py'>

# %%
sat_ds = ngs.open_file(query.workplan.iloc[0].path2file_local.as_posix(), verbose=True)
# Out:
# product name: ABI-L2-CTPC-M6
# identified as: ABI_L2_CTP.

# %%
list(sat_ds.ds.variables)

# %%
proj = sat_ds.project_on_sites(stations)

# %%
proj.projection2area.sel(site = 'BND', stats = 'mean', radius = 50, 
                         data_quality = 'high'
                        )
# Out:
# <xarray.Dataset>
# Dimensions:              ()
# Coordinates:
#     radius               int64 50
#     stats                <U4 'mean'
#     t                    datetime64[ns] 2023-08-01T13:02:36.128288
#     site                 <U3 'BND'
#     data_quality         <U15 'high'
# Data variables:
#     PRES                 float32 593.1
#     num_of_valid_points  int64 47

# %%
proj.projection2point

# %% [markdown]
# # Plot on map

# %%
scale = 0.5
width=2800000 *scale
height=1700000 * scale
a, bmap = surfrad.network.stations.Table_Mountain.plot(width=width, height=height)
bmap, pc, cb = sat_ds.plot('Temp', bmap = bmap)
bmap.drawcounties()
# f = plt.gcf()
# pc.set_clim(vmax= 10)

# %% [markdown]
# # Download and project

# %%
import pathlib as pl
import nesdis_aws
import nesdis_gml_synergy.satlab as ngs
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad
import os
os.getpid()
# Out:
# 20251

# %%
import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as surfrad

stations = surfrad.network.stations

# %%
def function(row, stations):#, alt_var = None):
    # if isinstance(alt_var, type(None)):
    #     alt_var = variable
    # read the file
    ngsinst = ngs.open_file(row.path2file_local)
    
    # project to stations
    projection = ngsinst.project_on_sites(stations)

    # merge closest gridpoint and area
    point = projection.projection2point.copy()#.sel(site = 'TBL')
    point['DQF'] = point.DQF.astype(int) # for some reason this was float64... because there are some nans in there
    
    # change var names to distinguish from area
    for var in ngsinst.valid_2D_variables:
        point = point.rename({var: f'{var}_on_pixel',})
    point = point.rename({'DQF': 'DQF_on_pixel'})
    
    # merge aerea and point
    ds = projection.projection2area.merge(point)#.rename({alt_var: f'{alt_var}_on_pixel', 'DQF': 'DQF_on_pixel'}))
    
    # add a time stamp
    dt = pd.Series([pd.to_datetime(ngsinst.ds.attrs['time_coverage_start']), pd.to_datetime(ngsinst.ds.attrs['time_coverage_end'])]).mean().to_datetime64()
    ds = ds.expand_dims({'datetime': [dt]}, )
    
    # there was another time coordinate without dimention though ... dropit
    ds = ds.drop_vars('t')

    # global attribute
    ds.attrs['info'] = ('This file contains a projection of satellite data onto SURFRAD sites.\n'
                         'It includes the closest pixel data as well as the average over circular\n'
                         'areas with various radii. Note, for the averaged data only data is\n'
                         'considered with a qulity flag given by the prooduct class in the\n'
                         'nesdis_gml_synergy package.')
    

    # save2file
    ds.to_netcdf(row.path2file_local_processed)
    return

# %%
product = 'CTP'
# alt_var = 'BCM'# None, if the varialbe name is not equal to product name
query = nesdis_aws.nesdis_aws.AwsQuery(
                                        path2folder_local=f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}/',
                                        satellite='16',
                                        product=f'ABI-L2-{product}',
                                        scan_sector='C',
                                        # start='2020-03-01 18:00:00',
                                        # end='2020-03-01 18:05:00',
                                        start='2020-03-01 00:00:00',
                                        end='2020-06-01 00:00:00',
                                        # start='2018-08-01 00:00:00',
                                        # end='2018-11-01 00:00:00',
                                        process = dict(#concatenate = 'daily',
                                                       function = lambda row: function(row, stations), #,, alt_var),
                                                       prefix = f'ABI_L2_{product}_projected2surfrad',
                                                       path2processed = f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}_projected2surfrad/'),
                                        # keep_files=True
                                      )

# pl.Path(f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}').mkdir()
# pl.Path(f'/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_{product}_projected2surfrad/').mkdir()

# %%
query.workplan
# Out:
# Empty DataFrame
# Columns: [path2file_aws, path2file_local, path2file_local_processed]
# Index: []

# %%
for i in query.workplan.iloc[0]:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_20251/3836681405.py in <cell line: 1>()
# ----> 1 for i in query.workplan.iloc[0]:
#       2     print(i)
#
# /mnt/telg/programs/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# /mnt/telg/programs/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1518
#    1519             # validate the location
# -> 1520             self._validate_integer(key, axis)
#    1521
#    1522             return self.obj._ixs(key, axis=axis)
#
# /mnt/telg/programs/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1450         len_axis = len(self.obj._get_axis(axis))
#    1451         if key >= len_axis or key < -len_axis:
# -> 1452             raise IndexError("single positional indexer is out-of-bounds")
#    1453
#    1454     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
query.process(raise_exception=True)

# %%
ds = xr.open_dataset('/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_CTP_projected2surfrad/ABI_L2_CTP_projected2surfrad_20200301_180114.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                     (datetime: 1, radius: 5, stats: 3,
#                                  data_quality: 1, site: 7)
# Coordinates:
#   * datetime                    (datetime) datetime64[ns] 2020-03-01T18:02:32...
#   * radius                      (radius) int64 5 10 25 50 100
#   * stats                       (stats) object 'median' 'mean' 'std'
#   * site                        (site) object 'BND' 'SXF' 'TBL' ... 'GWN' 'PSU'
#   * data_quality                (data_quality) object 'high'
# Data variables:
#     PRES                        (datetime, data_quality, radius, stats, site) float32 ...
#     num_of_valid_points         (datetime, data_quality, radius, site) int64 ...
#     PRES_on_pixel               (datetime, site) float32 ...
#     DQF_on_pixel                (datetime, site) int64 ...
#     argmin_x                    (datetime, site) float32 ...
#     argmin_y                    (datetime, site) float32 ...
#     lon_gritpoint               (datetime, site) float32 ...
#     lat_gridpoint               (datetime, site) float32 ...
#     lon_station                 (datetime, site) float32 ...
#     lat_station                 (datetime, site) float32 ...
#     distance_station_gridpoint  (datetime, site) float32 ...
# Attributes:
#     info:     This file contains a projection of satellite data onto SURFRAD ...

# %% [markdown]
# # Concatenate

# %%
reload(ngs)
# Out:
# <module 'nesdis_gml_synergy.satlab' from '/mnt/telg/prog/nesdis_gml_synergy/nesdis_gml_synergy/satlab.py'>

# %%
cc = ngs.Concatonator(path2scraped_files='/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_CTP_projected2surfrad/',
                 path2concat_files ='/nfs/stu3data2/Satellite_data/goes/16/ABI_L2_CTP_projected2surfrad_concat/',
                 datetime_format='ABI_L2_CTP_projected2surfrad_%Y%m%d_%H%M%S.nc',
                 test = False,)

# %%
cc.workplan
# Out:
# Empty DataFrame
# Columns: [path2scraped_files, datetime, date, product_name, path2concat_files, p2rf_exists]
# Index: []

# %%
ds=cc.concat_and_save(save=True, test=False, verbose=False)
