# %% [markdown]
# # Products

# %% [markdown]
# ## Available products on AWS

# %%
import nesdis_aws

# %%
nesdis_aws.nesdis_aws.readme()
# Out:
# follow link for readme: https://docs.opendata.aws/noaa-goes16/cics-readme.html

# %%
reload(nesdis_aws)
reload(nesdis_aws.nesdis_aws)
# Out:
# <module 'nesdis_aws.nesdis_aws' from '/export/htelg/prog/nesdis_aws/nesdis_aws/nesdis_aws.py'>

# %%
product_avail = nesdis_aws.nesdis_aws.get_available_products(verbose=False)
product_avail = avp
product_avail
# Out:
#                                                          longname        16-C  \
# product
# ABI-L1b-Rad                                             Radiances  2017-03-01
# ABI-L2-ACHA                                      Cloud Top Height  2019-12-03
# ABI-L2-ACHA2KM         Cloud Top Height 2km res. (todo: verify!!)  2023-03-24
# ABI-L2-ACHP2KM         Cloud Top Pressure 2km res. (todo: verify)  2023-03-24
# ABI-L2-ACHT                                 Cloud Top Temperature           -
# ABI-L2-ACM                                         Clear Sky Mask  2017-04-20
# ABI-L2-ACTP                                       Cloud Top Phase  2017-05-17
# ABI-L2-ADP                                      Aerosol Detection  2019-12-04
# ABI-L2-AICE                          Ice Concentration and Extent           -
# ABI-L2-AITA                                 Ice Age and Thickness           -
# ABI-L2-AOD                                  Aerosol Optical Depth  2017-05-25
# ...

# %% [markdown]
# ### what is available when

# %% [markdown]
# #### 16

# %%
avp[~(avp['16-C'] == '-')][avp['16-C'] < '2023-03-01'].loc[:,['longname', '16-C']]
# Out:
#                                                        longname        16-C
# product
# ABI-L1b-Rad                                           Radiances  2017-03-01
# ABI-L2-ACHA                                    Cloud Top Height  2019-12-03
# ABI-L2-ACM                                       Clear Sky Mask  2017-04-20
# ABI-L2-ACTP                                     Cloud Top Phase  2017-05-17
# ABI-L2-ADP                                    Aerosol Detection  2019-12-04
# ABI-L2-AOD                                Aerosol Optical Depth  2017-05-25
# ABI-L2-BRF    Land Surface Bidirectional Reflectance Factor ...  2021-08-19
# ABI-L2-CMIP                          Cloud and Moisture Imagery  2017-03-01
# ABI-L2-COD                                  Cloud Optical Depth  2017-06-09
# ABI-L2-CPS                                  Cloud Particle Size  2019-12-06
# ABI-L2-CTP                                   Cloud Top Pressure  2019-12-06
# ...

# %% [markdown]
# #### 17

# %%
avp[~(avp['17-C'] == '-')][avp['17-C'] < '2022-03-01'].loc[:,['longname', '17-C']]
# Out:
#                                                        longname        17-C
# product
# ABI-L1b-Rad                                           Radiances  2018-08-29
# ABI-L2-ACHA                                    Cloud Top Height  2019-12-03
# ABI-L2-ACM                                       Clear Sky Mask  2018-08-28
# ABI-L2-ACTP                                     Cloud Top Phase  2018-08-28
# ABI-L2-ADP                                    Aerosol Detection  2019-12-04
# ABI-L2-AOD                                Aerosol Optical Depth  2018-08-28
# ABI-L2-BRF    Land Surface Bidirectional Reflectance Factor ...  2021-08-19
# ABI-L2-CMIP                          Cloud and Moisture Imagery  2018-08-29
# ABI-L2-COD                                  Cloud Optical Depth  2018-08-28
# ABI-L2-CPS                                  Cloud Particle Size  2019-12-06
# ABI-L2-CTP                                   Cloud Top Pressure  2019-12-06
# ...
