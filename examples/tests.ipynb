# %%
import GeoLeoXtract as glx
import warnings
warnings.filterwarnings('ignore')
from importlib import reload

# import atmPy.data_archives.NOAA_ESRL_GMD_GRAD.surfrad.surfrad as atmsrf

# %%
sites = {'lon': -105.2705, 'lat': 40.015, 'alt': 1500, 'abb': 'bld', 'earthdata_granule': 'h09v04'}
# sites = atmsrf.network.stations.list #surfrad sites

# %%
if 0:
    p2fld_base = pl.Path('/home/grad/htelg/tmp/')
else:
    p2fld_base = pl.Path('/home/hagen/tmp/')

# %% [markdown]
# ## MERRA M2T1NXAER

# %%
reload(glx.scrapers.earthdata)
reload(glx.satlab)
reload(glx.merra)
reload(glx.file_io)
reload(glx.projector.prolab)
reload(glx)
# Out:
# <module 'GeoLeoXtract' from '/home/hagen/prog/GeoLeoXtract/GeoLeoXtract/__init__.py'>

# %%
data_product = 'M2T1NXAER'
p2fld_out = p2fld_base.joinpath('{product}/projected'.format(product = data_product))
p2fld_orig = p2fld_base.joinpath('{product}/orig'.format(product = data_product))
p2fld_orig.mkdir(exist_ok=True)
p2fld_out.mkdir(exist_ok=True)

# %%
scraper = glx.scrapers.earthdata.CMRSraperGlobal
scraper_kwargs = dict(product=data_product,
                        p2fld_orig = p2fld_orig,
                        reporter=None,
                        overwrite=True,
                        verbose=True,
                        test = 'full',
                     )

product = glx.merra.make_product_v01
product_kwargs = dict()

self = glx.projector.prolab.ChunckProcessor(
                                            start='20230101',
                                            end='20240101',
                                            chunksize='MS',
                                            sites={'lon': -105.2705, 'lat': 40.015, 'alt': 1500, 'abb': 'bld', 'earthdata_granule': 'h09v04'},
                                            p2fld_out=p2fld_out,
                                            name_addon='projection',
                                            scraper=scraper,
                                            scraper_kwargs=scraper_kwargs,
                                            product=product,
                                            product_kwargs=product_kwargs,
                                            overwrite=True,
                                            test='full',
                                            remove_originals = True,
                                            )

# %%
self.process()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/hagen/tmp/M2T1NXAER/projected/M2T1NXAER_projection_202301.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '9c5a2a91-50f8-4dff-b738-c5385409a4dc']
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 self.process()
#
# File ~/prog/GeoLeoXtract/GeoLeoXtract/projector/prolab.py:151, in ChunckProcessor.process(self, verbose)
#     149 def process(self, verbose = False):
#     150     for idx, row in self.workplan.iterrows():
# --> 151         self.process_item(row, verbose = verbose)
#
# File ~/prog/GeoLeoXtract/GeoLeoXtract/projector/prolab.py:141, in ChunckProcessor.process_item(self, row, test, verbose)
#     139 if verbose:
#     140     print(f'saving projection to {row.p2f_out}')
# --> 141 dsa.to_netcdf(row.p2f_out)
#     143 #### remove original files
#     144 if self.remove_originals:
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/core/dataset.py:2373, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf, auto_complex)
#    2370     encoding = {}
#    2371 from xarray.backends.api import to_netcdf
# -> 2373 return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    2374     self,
#    2375     path,
#    2376     mode=mode,
#    2377     format=format,
#    2378     group=group,
#    2379     engine=engine,
#    2380     encoding=encoding,
#    2381     unlimited_dims=unlimited_dims,
#    2382     compute=compute,
#    2383     multifile=False,
#    2384     invalid_netcdf=invalid_netcdf,
#    2385     auto_complex=auto_complex,
#    2386 )
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/api.py:1888, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf, auto_complex)
#    1885 if auto_complex is not None:
#    1886     kwargs["auto_complex"] = auto_complex
# -> 1888 store = store_open(target, mode, format, group, **kwargs)
#    1890 if unlimited_dims is None:
#    1891     unlimited_dims = dataset.encoding.get("unlimited_dims", None)
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:452, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     448     kwargs["auto_complex"] = auto_complex
#     449 manager = CachingFileManager(
#     450     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     451 )
# --> 452 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:393, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     391 self._group = group
#     392 self._mode = mode
# --> 393 self.format = self.ds.data_model
#     394 self._filename = self.ds.filepath()
#     395 self.is_remote = is_remote_uri(self._filename)
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:461, in NetCDF4DataStore.ds(self)
#     459 @property
#     460 def ds(self):
# --> 461     return self._acquire()
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:455, in NetCDF4DataStore._acquire(self, needs_lock)
#     454 def _acquire(self, needs_lock=True):
# --> 455     with self._manager.acquire_context(needs_lock) as root:
#     456         ds = _nc4_require_group(root, self._group, self._mode)
#     457     return ds
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File ~/programms/anaconda3/envs/py312/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2521, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2158, in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: '/home/hagen/tmp/M2T1NXAER/projected/M2T1NXAER_projection_202301.nc'

# %%
ds = xr.open_dataset(self.masterplan.p2f_out.iloc[0])

# %%
ds
